# %% [markdown]
# <a href="https://colab.research.google.com/github/chauhan2000/100DaysOfCode/blob/master/Rachit_49_bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/data.csv")
print(df["RM"].isna().sum())
# Out:
# 5

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/data.csv")
data=df.dropna()
print(data["RM"].isna().sum())
# Out:
# 0

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/data.csv")
del df['RAD']

# %%
print(data)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0    0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 506  0.98765   0.0  12.50     0  0.561  ...  320     23.0  396.00  12.00  12.0
# 507  0.23456   0.0  12.50     0  0.561  ...  320     23.0  343.00  25.00  32.0
# 508  0.44433   0.0  12.50     0  0.561  ...  320     23.0  343.00  21.00  54.0
# 509  0.77763   0.0  12.70     0  0.561  ...  329     23.0  343.00  76.00  67.0
# 510  0.65432   0.0  12.80     0  0.561  ...  345     23.0  321.00  45.00  24.0
#
# [506 rows x 14 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv("/content/data.csv")
df1=df
del df1['string']
r = df1.corr()
sns.heatmap(r,annot= True)

# %%
sns.set_style('whitegrid')
sns.distplot(df['B'],kde=False,color='Blue',bins=30)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
sns.countplot(x='TAX', data=df)
plt.show()

# %%
plt.scatter(df["LSTAT"],df["MEDV"])
plt.show()
